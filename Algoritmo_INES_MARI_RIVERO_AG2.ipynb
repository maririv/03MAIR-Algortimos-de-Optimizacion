# %% [markdown]
# <a href="https://colab.research.google.com/github/maririv/03MAIR-Algortimos-de-Optimizacion/blob/main/Algoritmo_INES_MARI_RIVERO_AG2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Actividad guiada 2

# %% [markdown]
# Inés Marí Rivero
#
# https://github.com/maririv

# %% [markdown]
# ### Descenso del gradiente

# %%
import math
import matplotlib.pyplot as plt
import numpy as np
import random

# %%
#función: f(x,y) = x2 +y2
f = lambda X: X[0]**2 + X[1]**2 #función
df = lambda X: [2*X[0], 2*X[1]] #gradiente

# %%
resolucion = 30
rango = 2.5
X = np.linspace(-rango, rango, resolucion)
Y = np.linspace(-rango, rango, resolucion)
Z = np.zeros((resolucion, resolucion))

for ix, x in enumerate(X):
  for iy, y in enumerate(Y):
    Z[ix, iy] = f([x,y])

contour = plt.contour(X,Y,Z, resolucion)
cbar = plt.colorbar(contour)

P = [random.uniform(-rango, rango), random.uniform(-rango, rango)]
plt.plot(P[0], P[1], "o", c="blue")
TA = 0.05

for _ in range(500):
  grad = df(P)
  P[0], P[1] = P[0] - TA*grad[0], P[1] - TA*grad[1]
  plt.plot(P[0], P[1],  "o", c="red")

plt.plot(P[0], P[1],  "o", c="green")
print("Solucion: ", P, f(P))
# Out:
# Solucion:  [2.90941150433498e-23, -3.165123859993465e-23] 1.8482684350656664e-45

# %%
def gradient_descent(start, step = 0.001, tresh = 0.01, max_steps = 1e5):
  min = start
  i = 0
  while(True):
    if i > max_steps:
      return min
    new_point = np.array(min) - step * np.array(df(min))

    if (new_point - min).all() < tresh:
      return min

    min = new_point
    i+=1


gradient_descent([1,1])
# Out:
# array([1.13047062e-87, 1.13047062e-87])
